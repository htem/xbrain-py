# %%
"""                                                                                                 
Separate file to keep segmentation paramters in it. E.g,                                            
stopping_criterion = 0.47                                                                           
vessel_probability_threshold = .68                                                                  
dilation_size = 3                                                                                   
minimum_size = 4000
"""
from segmentation_param import *
import numpy as np
import scipy.io as sio
from PIL import Image
import ndparse as ndp
import time
import matplotlib.pyplot as plt

# %%
#segmentation entry point functions
from read_tiff_files import read_tiff_files
from classify_pixel import classify_pixel
import detect_cells
import segment_vessels 
import create_synth_dict
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Following parameters to be passed in as parameters to this script. 
tiff_files_location = '/home/aaron/Dropbox (htem)/AK/Xray/xbrain/data/ppc_images'
classifier_file = '/home/aaron/Dropbox (htem)/AK/Xray/xbrain/LDMS2_PPC_2.ilp'

# %%
# Read tiff stack files - output of tomopy. 
input_data = read_tiff_files(tiff_files_location)

# %%
print("input_data shape", input_data.shape)
# Out:
# ('input_data shape', (449, 297, 87))

# %%
# %matplotlib inline

# %%
ndp.plot(input_data, slice=50)

# %%
# Compute cell and vessel probability map.
probability_maps = classify_pixel(input_data, classifier_file, threads=no_of_threads, ram=ram_size)
# Out:
# INFO ilastik_main: Starting ilastik from "/home/aaron/anaconda2/envs/ilastik-dev".
# INFO ilastik_main: Starting ilastik from "/home/aaron/anaconda2/envs/ilastik-dev".
# INFO ilastik_main: Starting ilastik from "/home/aaron/anaconda2/envs/ilastik-dev".
# INFO ilastik_main: Starting ilastik from "/home/aaron/anaconda2/envs/ilastik-dev".
# Starting ilastik from "/home/aaron/anaconda2/envs/ilastik-dev".
# INFO ilastik_main: Resetting lazyflow thread pool with 8 threads.
# INFO ilastik_main: Resetting lazyflow thread pool with 8 threads.
# INFO ilastik_main: Resetting lazyflow thread pool with 8 threads.
# INFO ilastik_main: Resetting lazyflow thread pool with 8 threads.
# INFO ilastik_main: Configuring lazyflow RAM limit to 3.9GiB
# INFO ilastik_main: Configuring lazyflow RAM limit to 3.9GiB
# INFO ilastik_main: Configuring lazyflow RAM limit to 3.9GiB
# INFO ilastik_main: Configuring lazyflow RAM limit to 3.9GiB
# INFO lazyflow.utility.memory: Available memory set to 3.9GiB
# INFO lazyflow.utility.memory: Available memory set to 3.9GiB
# INFO lazyflow.utility.memory: Available memory set to 3.9GiB
# INFO lazyflow.utility.memory: Available memory set to 3.9GiB
# INFO ilastik.shell.projectManager: Opening Project: /home/aaron/Dropbox (htem)/AK/Xray/xbrain/LDMS2_PPC_2.ilp
# INFO ilastik.shell.projectManager: Opening Project: /home/aaron/Dropbox (htem)/AK/Xray/xbrain/LDMS2_PPC_2.ilp
# INFO ilastik.shell.projectManager: Opening Project: /home/aaron/Dropbox (htem)/AK/Xray/xbrain/LDMS2_PPC_2.ilp
# INFO ilastik.shell.projectManager: Opening Project: /home/aaron/Dropbox (htem)/AK/Xray/xbrain/LDMS2_PPC_2.ilp
# input_data.shape (449, 297, 87)
# label_names, label_colors, probability_colors ['Vessels', 'Cells', 'Bg'] [(255, 0, 0), (0, 255, 0), (255, 255, 0)] [(255, 0, 0), (0, 255, 0), (255, 255, 0)]
# INFO ilastik.applets.batchProcessing.batchProcessingApplet: Exporting to in-memory array.
# INFO ilastik.applets.batchProcessing.batchProcessingApplet: Exporting to in-memory array.
# INFO ilastik.applets.batchProcessing.batchProcessingApplet: Exporting to in-memory array.
# INFO ilastik.applets.batchProcessing.batchProcessingApplet: Exporting to in-memory array.
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per pixel is 240.0B * safety factor (2.0)
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per pixel is 240.0B * safety factor (2.0)
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per pixel is 240.0B * safety factor (2.0)
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per pixel is 240.0B * safety factor (2.0)
# INFO lazyflow.utility.bigRequestStreamer: determining blockshape assuming available_ram is 2.9GiB, split between 8 threads
# INFO lazyflow.utility.bigRequestStreamer: determining blockshape assuming available_ram is 2.9GiB, split between 8 threads
# INFO lazyflow.utility.bigRequestStreamer: determining blockshape assuming available_ram is 2.9GiB, split between 8 threads
# INFO lazyflow.utility.bigRequestStreamer: determining blockshape assuming available_ram is 2.9GiB, split between 8 threads
# INFO lazyflow.utility.bigRequestStreamer: Chose blockshape: (97, 97, 87, 3)
# INFO lazyflow.utility.bigRequestStreamer: Chose blockshape: (97, 97, 87, 3)
# INFO lazyflow.utility.bigRequestStreamer: Chose blockshape: (97, 97, 87, 3)
# INFO lazyflow.utility.bigRequestStreamer: Chose blockshape: (97, 97, 87, 3)
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per block is 374.7MiB
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per block is 374.7MiB
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per block is 374.7MiB
# INFO lazyflow.utility.bigRequestStreamer: Estimated RAM usage per block is 374.7MiB
# DEBUG lazyflow.operators.classifierOperators: Features took 0.958931 seconds, Prediction took 3.39537 seconds for roi: [0, 0, 0, 0] : [97, 97, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 0.958931 seconds, Prediction took 3.39537 seconds for roi: [0, 0, 0, 0] : [97, 97, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 0.958931 seconds, Prediction took 3.39537 seconds for roi: [0, 0, 0, 0] : [97, 97, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 0.958931 seconds, Prediction took 3.39537 seconds for roi: [0, 0, 0, 0] : [97, 97, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 4.052657 seconds, Prediction took 0.497993 seconds for roi: [0, 291, 0, 0] : [97, 297, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 4.052657 seconds, Prediction took 0.497993 seconds for roi: [0, 291, 0, 0] : [97, 297, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 4.052657 seconds, Prediction took 0.497993 seconds for roi: [0, 291, 0, 0] : [97, 297, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 4.052657 seconds, Prediction took 0.497993 seconds for roi: [0, 291, 0, 0] : [97, 297, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 1.68324 seconds, Prediction took 3.617742 seconds for roi: [0, 194, 0, 0] : [97, 291, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 1.68324 seconds, Prediction took 3.617742 seconds for roi: [0, 194, 0, 0] : [97, 291, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 1.68324 seconds, Prediction took 3.617742 seconds for roi: [0, 194, 0, 0] : [97, 291, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 1.68324 seconds, Prediction took 3.617742 seconds for roi: [0, 194, 0, 0] : [97, 291, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took
 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 0.574923 seconds, Prediction took 3.350227 seconds for roi: [388, 194, 0, 0] : [449, 291, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 6.382498 seconds, Prediction took 1.90569 seconds for roi: [388, 97, 0, 0] : [449, 194, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 6.382498 seconds, Prediction took 1.90569 seconds for roi: [388, 97, 0, 0] : [449, 194, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 6.382498 seconds, Prediction took 1.90569 seconds for roi: [388, 97, 0, 0] : [449, 194, 87, 3]
# DEBUG lazyflow.operators.classifierOperators: Features took 6.382498 seconds, Prediction took 1.90569 seconds for roi: [388, 97, 0, 0] : [449, 194, 87, 3]
# predictions.dtype, predictions.shape float32 (449, 297, 87, 3)
# DONE.

# %%
cell_prob_map = probability_maps[:, :, :, 1]
vessel_prob_map = probability_maps[:, :, :, 0]

# %%
ndp.plot(cell_prob_map, slice=50, cmap1='hot')

# %%
ndp.plot(vessel_prob_map, slice=50, cmap1='hot')

# %%
# Parallel operation to detect cells to be designed. Hard coded for now - cut 400x400x40 volume.
crop_probability_maps = probability_maps[0:100,:,:]
crop_input_data = input_data[0:100,:,:]
crop_cell_prob_map = crop_probability_maps[:, :, :, 1]
crop_vessel_prob_map = crop_probability_maps[:, :, :, 0]

# %%
print(cell_map.shape)
# Out:
# (100, 100, 10)

# %%
ndp.plot(crop_input_data, slice=10, cmap1='gray')

# %%
ndp.plot(crop_cell_prob_map, slice=10, cmap1='gray')

# %%
cell_probability_threshold=0.2
stopping_criterion=0.7
initial_template_size=6
dilation_size=2
max_no_cells=10000

print(cell_probability_threshold,stopping_criterion,initial_template_size,dilation_size,max_no_cells)

t=time.time()
centroids, cell_map = detect_cells.detect_cells(crop_cell_prob_map, cell_probability_threshold, stopping_criterion, initial_template_size, dilation_size, max_no_cells)
print(time.time()-t)
# Out:
# (0.2, 0.7, 6, 2, 10000)
# Iteration remaining =  9999 Correlation =  [[ 0.93803579]]
# Iteration remaining =  9949 Correlation =  [[ 0.82410717]]
# Iteration remaining =  9899 Correlation =  [[ 0.79196429]]
# Iteration remaining =  9849 Correlation =  [[ 0.76053572]]
# Iteration remaining =  9799 Correlation =  [[ 0.73392862]]
# Iteration remaining =  9749 Correlation =  [[ 0.71089286]]
# Cell Detection is done
# 37.0994229317

# %%
print(crop_cell_prob_map.shape)
print(cell_map.shape)
print(centroids.shape)
# Out:
# (100, 100, 87)
# (100, 100, 87)
# (273, 4)

# %%
print("Cell Segmentation")
ndp.plot(crop_cell_prob_map, cell_map, slice = 80, alpha = 0.5)
# Out:
# Cell Segmentation

# %%
ndp.plot(vessel_prob_map, slice=50, cmap1='hot')

# %%
print(vessel_prob_map.shape)
# Out:
# (449, 297, 87)

# %%
plt.hist(vessel_prob_map.flatten())
plt.show()

# %%
reload(segment_vessels)
vessel_probability_threshold=0.5
dilation_size= 1
minimum_size = 1
vessel_map = foo(vessel_prob_map, vessel_probability_threshold, dilation_size, minimum_size) 
print("Vessel Segmentation")
ndp.plot(vessel_map, slice = 50, alpha = 0.5)
# Out:
# Vessel Segmentation

# %%
print(vessel_map.shape)
# Out:
# (449, 297, 87)
